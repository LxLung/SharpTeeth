# %% [markdown]
# ## Micrograd from Andrej Karpathy

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
xs = np.arange(-5,5,0.25)
a,b,c = (1,2,3)
ys = a*xs**2+b*xs+c
plt.plot(xs,ys)
plt.show()

# %%
x = 5.0
f1 = -3*x**2-2*x+10
h=0.000001
print(f1)
x+=h
f2 = -3*x**2-2*x+10
print(f2)
print("derviative of f at x=5",int((f2-f1)/h))
# Out:
# -75.0
# -75.000032000003
# derviative of f at x=5 -32

# %%
class Value:
    def __init__(self,data):
        self.data = data

    def __repr__(self):
        return f"Value(data={self.data})"

    def __add__(self,other):
        out = Value(self.data + other.data)
        return out
    
    def __mul__(self, other):
        out = Value(self.data*other.data)
        return out
    
    def __truediv__(self,other):
        out = Value(self.data/other.data)    
        return out

a = Value(2)
b = Value(-3)
c = Value(10)
d = a*b + c
print(d)
# Out:
# Value(data=4)
